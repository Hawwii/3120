# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
df = pd.read_csv('Spotify_Youtube.csv')

# %%
sns.scatterplot(data=df, x='Key', y='Stream')
plt.title('Key and Number of Streams')
plt.xlabel('Key')
plt.ylabel('Number of Streams')
plt.show()

# %%
sns.scatterplot(data=df, x='Tempo', y='Stream')
plt.title('Tempo and Number of Streams')
plt.xlabel('Tempo')
plt.ylabel('Number of Streams')
plt.show()

# %%
sns.scatterplot(data=df, x='Acousticness', y='Stream')
plt.title('Acousticness and Number of Streams')
plt.xlabel('Acousticness')
plt.ylabel('Number of Streams')
plt.show()

# %%
sns.scatterplot(data=df, x='Instrumentalness', y='Stream')
plt.title('Instrumentalness and Number of Streams')
plt.xlabel('Instrumentalness')
plt.ylabel('Number of Streams')
plt.show()

# %%
sns.scatterplot(data=df, x='Speechiness', y='Stream')
plt.title('Speechiness and Number of Streams')
plt.xlabel('Speechiness')
plt.ylabel('Number of Streams')
plt.show()
